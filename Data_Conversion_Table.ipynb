# %%
import pandas as pd

# %%
df = pd.read_csv("Resources/cities.csv", sep=",")

# %%
df.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_85389514_fdd7_11ea_a2f8_d81265eae928" ><thead>    <tr>        <th class="col_heading level0 col0" >City_ID</th>        <th class="col_heading level0 col1" >City</th>        <th class="col_heading level0 col2" >Cloudiness</th>        <th class="col_heading level0 col3" >Country</th>        <th class="col_heading level0 col4" >Date</th>        <th class="col_heading level0 col5" >Humidity</th>        <th class="col_heading level0 col6" >Lat</th>        <th class="col_heading level0 col7" >Lng</th>        <th class="col_heading level0 col8" >Max Temp</th>        <th class="col_heading level0 col9" >Wind Speed</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_85389514_fdd7_11ea_a2f8_d81265eae928row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_85389514_fdd7_11ea_a2f8_d81265eae928row0_col1" class="data row0 col1" >jacareacanga</td>
# ...

# %%
df
df.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_a35b7506_fdd7_11ea_b9c4_d81265eae928" ><thead>    <tr>        <th class="col_heading level0 col0" >City_ID</th>        <th class="col_heading level0 col1" >City</th>        <th class="col_heading level0 col2" >Cloudiness</th>        <th class="col_heading level0 col3" >Country</th>        <th class="col_heading level0 col4" >Date</th>        <th class="col_heading level0 col5" >Humidity</th>        <th class="col_heading level0 col6" >Lat</th>        <th class="col_heading level0 col7" >Lng</th>        <th class="col_heading level0 col8" >Max Temp</th>        <th class="col_heading level0 col9" >Wind Speed</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a35b7506_fdd7_11ea_b9c4_d81265eae928row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_a35b7506_fdd7_11ea_b9c4_d81265eae928row0_col1" class="data row0 col1" >jacareacanga</td>
# ...

# %%
df.to_html("")
